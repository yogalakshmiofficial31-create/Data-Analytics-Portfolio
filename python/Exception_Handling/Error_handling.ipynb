# %%
try:
 age = int(input('Enter age'))
 print(age)
except:
 print('invalid age')
# Out:
# invalid age

# %%
try:
 age = int(inp('Enter age'))
 print(age)
except:
 print('invalid age')
# Out:
# invalid age

# %%
try:
    age = int(inp('Enter age'))
    print(age)
except ValueError:
    print('Invalid age')
except SyntaxError:
    print('Invalid syntax')

# %%
try:
    print(Process)
except:
    print(Error)
Final:
     print('Completed')

# %%
try:
    o = open('sales.csv','r')
except FileNotFoundError:
    print('File not available in your directory')
finally:
    print('file opened')

# %%
try:
    student={'Name':'yoga'}
    print(age)
except:
    print('key value error')
# Out:
# key value error
