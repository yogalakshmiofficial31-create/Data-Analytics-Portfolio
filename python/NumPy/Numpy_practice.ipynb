# %%
import numpy as np
#array - collection of same data type
calls  = np.array([5,7,8,9,11])
print (calls)
# Out:
# [ 5  7  8  9 11]

# %%
#pip install packages = 'pip install pakages'
import numpy as np
calls = np.array([['jan','feb','mar'],[300,400,500]])
print (calls)
# Out:
# [['jan' 'feb' 'mar']
#  ['300' '400' '500']]

# %%
import numpy as np
calls = np.array([['jan','feb','mar'],[300,400,500]])
calls[1]
# Out:
# array(['300', '400', '500'], dtype='<U21')

# %%
import numpy as np
calls = np.array([['jan','feb','mar'],[300,400,500]])
calls[1,:]
# Out:
# array(['300', '400', '500'], dtype='<U21')

# %%
import numpy as np
calls = np.array([['jan','feb','mar'],[300,400,500]])
calls[0,:]
# Out:
# array(['jan', 'feb', 'mar'], dtype='<U21')

# %%
calls.shape
# Out:
# (2, 3)

# %%
monthlycalls = np.array([['Jan','Mar','feb'],
                         [2,2,7],
                         [5,6,5],
                         [3,8,4]])
monthlycalls[1,2]
# Out:
# np.str_('7')

# %%
monthlycalls = np.array([['Jan','Mar','feb'],
                         [2,2,7],
                         [5,6,5],
                         [3,8,4]])
monthlycalls[1]
# Out:
# array(['2', '2', '7'], dtype='<U21')

# %%
import numpy as np
numbers = np.array([3,6,4,2,3,1])
numbers = [numbers>3]
print(numbers)
# Out:
# [array([False,  True,  True, False, False, False])]

# %%
import numpy as np
numbers = np.array([3,6,4,2,3,1,7,9])
numbers = [2&4]
print(numbers)
# Out:
# [0]

# %%
import numpy as np
numbers = np.array([3,6,4,2,3,1,7,9])
filtered_numbers = numbers[(numbers>=2) & (numbers <=9)]
print(filtered_numbers)
# Out:
# [3 6 4 2 3 7 9]

# %%
import numpy as np
numbers = np.array([3,6,4,2,3,1,7,9])
np.sum(numbers)
# Out:
# np.int64(35)

# %%
import numpy as np
numbers = np.array([3,6,4,2,3,1,7,9])
np.max(numbers)
# Out:
# np.int64(9)

# %%
import numpy as np
numbers = np.array([3,6,4,2,3,1,7,9])
np.min(numbers)
# Out:
# np.int64(1)

# %%
import numpy as np
numbers = np.array([3,6,4,2,3,1,7,9])
np.mean(numbers)
# Out:
# np.float64(4.375)

# %%
import numpy as np
numbers = np.array([3,6,4,2,3,1,7,9])
np.std(numbers)
# Out:
# np.float64(2.54644359843292)

# %%
#2 dimensional array
monthlycalls = np.array([[5,6,5],
                         [3,8,4]])
total_calls = np.sum(monthlycalls)
print('number_of_calls',total_calls)
# Out:
# number_of_calls 31

# %%
monthlycalls = np.array([['Jan','Mar','feb'],
                         [2,2,7],
                         [5,6,5],
                         [3,8,4]])
np.sum(monthlycalls[1:].astype(int))
# Out:
# np.int64(42)

# %%
North = np.array([5,100,30])
South = np.array([3,2,5])
np.concatenate((North,South))
# Out:
# array([  5, 100,  30,   3,   2,   5])

# %%
North = np.array([5,100,30])
South = np.array([3,2,5])
np.add(North,South)
# Out:
# array([  8, 102,  35])

# %%
month_total = np.array([['Jan','Feb','Mar'],
                        [200,30,400],
                        [30,50,80]])
column_totals=np.sum(month_total[1:].astype(int),axis=0)
print(column_totals)
# Out:
# [230  80 480]

# %%
rows=np.array([40,80,50,20,30])
result = np.split(rows,[2,4])
print(result)
# Out:
# [array([40, 80]), array([50, 20]), array([30])]
